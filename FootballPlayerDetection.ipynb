# %% [markdown]
# Connect to Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install YOLOv8
#
#  # Pip install (recommended)
# !pip install ultralytics
#
# import ultralytics
# ultralytics.checks()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 56.3/56.3 MB 213.7 MB/s eta 0:00:01
# ERROR: Operation cancelled by user

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/112.6 GB disk)

# %% [markdown]
# **# YOLO8 Training HyperParameters**
#
#
#
# **task**= detect or segment
#
# **mode**= train, val
#
# **model**= path to model file, i.e. yolov8n.pt, yolov8n.yaml
#
# **data**= path to data file dataset.yaml
#
# **epochs**= number of epochs to train for
#
# **imgsz**= size of input images as integer
#
# **batch**= number of images per batch
#
# **projec**t= project traing results saving path
#
# **name**= experiment name

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/dataset.yaml epochs=12 imgsz=1920 batch=8 project=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TrainingResult name=FootballDetection
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **Inference using trained YOLO8**

# %% [markdown]
# **Prediction to Detect the Test Images**

# %%
# !yolo task=detect \
    mode=predict \
    model=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TrainingResult/FootballDetection2/weights/best.pt \
    conf=0.55 \
    source=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/122 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-10_jpg.rf.0955a950bbe84886790fd36798248863.jpg: 1088x1920 1 Ball, 20 Players, 3 Referees, 32.6ms
# image 2/122 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-26_jpg.rf.538dc3be8ff16d7fac0bf539698abb77.jpg: 1088x1920 21 Players, 1 Referee, 24.4ms
# image 3/122 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-28_jpg.rf.3a4c1bc5a6b527a7c19c1908a5df73aa.jpg: 1088x1920 21 Players, 2 Referees, 24.6ms
# image 4/122 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-2_jpg.rf.992311fb905c1e25061f89c7919c713c.jpg: 1088x1920 22 Players, 3 Referees, 24.4ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/DetectionResults

# %% [markdown]
# **Detection for Videos**

# %%
# !yolo task=detect \
    mode=predict \
    model=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TrainingResult/FootballDetection2/weights/best.pt \
    conf=0.55 \
    source=/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/2 (frame 1/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 13 Players, 1 Referee, 32.5ms
# video 1/2 (frame 2/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 13 Players, 1 Referee, 24.4ms
# video 1/2 (frame 3/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 1 Ball, 12 Players, 1 Referee, 24.5ms
# video 1/2 (frame 4/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 1 Ball, 13 Players, 1 Referee, 24.4ms
# video 1/2 (frame 5/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 1 Ball, 13 Players, 1 Referee, 24.4ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/DetectionResults
